# %% [markdown]
# ### 2D Implementation of paper [ProlificDreamer: High-Fidelity and Diverse Text-to-3D Generation with Variational Score Distillation](https://arxiv.org/abs/2305.16213)

# %%
### clone the repo
# !git clone https://github.com/Skyepulse/test_prolific_dreamer_2D.git
# Out:
# Cloning into 'test_prolific_dreamer_2D'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 195 (delta 117), reused 195 (delta 117), pack-reused 0 (from 0)
# Receiving objects: 100% (195/195), 13.52 MiB | 15.21 MiB/s, done.
# Resolving deltas: 100% (117/117), done.

# %%
# !nvidia-smi
# Out:
# Thu Mar  5 01:39:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
cd test_prolific_dreamer_2D
# Out:
# /content/test_prolific_dreamer_2D

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...

# %%
# !python -c "import torch; print(f'torch {torch.__version__}'); import diffusers; print(f'diffusers {diffusers.__version__}'); import transformers; print(f'transformers {transformers.__version__}'); import peft; print(f'peft {peft.__version__}'); import huggingface_hub; print(f'hub {huggingface_hub.__version__}'); print('All imports OK')"
# Out:
# torch 2.2.0+cu121
# diffusers 0.28.0
# transformers 4.44.0
# peft 0.7.1
# hub 0.24.0
# All imports OK

# %%
PROMPT = "A steampunk girl with steampunk goggles holding a steampunk gun."

# %% [markdown]
# # VSD EXPERIMENT

# %%
# !python prolific_dreamer2d.py \
        --num_steps 500 --log_steps 72 \
        --seed 1024 --lr 0.03 --phi_lr 0.0001 --use_t_phi true \
        --model_path 'CompVis/stable-diffusion-v1-4' \
        --loss_weight_type '1m_alphas_cumprod' --t_schedule 'random' \
        --generation_mode 'vsd' \
        --phi_model 'lora' --lora_scale 1. --lora_vprediction false \
        --prompt "A steampunk girl with steampunk goggles holding a steampunk gun." \
        --height 512 --width 512 --batch_size 1 --guidance_scale 7.5 \
        --log_progress true --save_x0 true --save_phi_model true \
        --log_gif true
# Out:
# 2026-03-05 01:39:54.311600: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772674794.331667   50409 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772674794.337758   50409 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772674794.353205   50409 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# # SDS Experiment 100 CFG
# >

# %%
# !python prolific_dreamer2d.py \
        --num_steps 500 --log_steps 72 \
        --seed 1024 --lr 0.03 \
        --model_path 'CompVis/stable-diffusion-v1-4' \
        --loss_weight_type '1m_alphas_cumprod' --t_schedule 'random' \
        --generation_mode 'sds' \
        --prompt "A steampunk girl with steampunk goggles holding a steampunk gun." \
        --height 512 --width 512 --batch_size 1 --guidance_scale 100 \
        --log_progress true --save_x0 true \
        --log_gif true
# Out:
# 2026-03-05 01:54:18.063354: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772675658.099332   54198 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772675658.109558   54198 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772675658.134455   54198 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# # SDS WITH 7.5 guidance

# %%
# !python prolific_dreamer2d.py \
        --num_steps 500 --log_steps 72 \
        --seed 1024 --lr 0.03 \
        --model_path 'CompVis/stable-diffusion-v1-4' \
        --loss_weight_type '1m_alphas_cumprod' --t_schedule 'random' \
        --generation_mode 'sds' \
        --prompt "A steampunk girl with steampunk goggles holding a steampunk gun." \
        --height 512 --width 512 --batch_size 1 --guidance_scale 7.5 \
        --log_progress true --save_x0 true \
        --log_gif true
# Out:
# 2026-03-05 01:59:28.225990: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772675968.245504   55542 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772675968.251680   55542 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772675968.266785   55542 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !zip -r results.zip work_dir
# Out:
#   adding: work_dir/ (stored 0%)
#   adding: work_dir/prolific_dreamer2d-20260305_0139-vsd-lr_0.03-cfg_7.5-bs_1-num_steps_500-tschedule_random-loss_weight_1m_alphas_cumprod_lora/ (stored 0%)
#   adding: work_dir/prolific_dreamer2d-20260305_0139-vsd-lr_0.03-cfg_7.5-bs_1-num_steps_500-tschedule_random-loss_weight_1m_alphas_cumprod_lora/A_steampunk_girl_with_steampunk_goggles_holding_a_steampunk_gun._prgressive.png (deflated 0%)
#   adding: work_dir/prolific_dreamer2d-20260305_0139-vsd-lr_0.03-cfg_7.5-bs_1-num_steps_500-tschedule_random-loss_weight_1m_alphas_cumprod_lora/A_steampunk_girl_with_steampunk_goggles_holding_a_steampunk_gun._image_step432_t838.png (deflated 0%)
#   adding: work_dir/prolific_dreamer2d-20260305_0139-vsd-lr_0.03-cfg_7.5-bs_1-num_steps_500-tschedule_random-loss_weight_1m_alphas_cumprod_lora/A_steampunk_girl_with_steampunk_goggles_holding_a_steampunk_gun._image_step216_t72.png (deflated 0%)
# ...

# %%
from google.colab import files
files.download("results.zip")
